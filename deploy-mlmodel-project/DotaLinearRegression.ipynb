# %%
import json
from datetime import datetime
import pandas as pd
import teams

# %%
error_list = []

# %%
tundra_esports_data = teams.Team('tundra_esports_data.json')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 tundra_esports_data = teams.Team('tundra_esports_data.json')
#
# NameError: name 'teams' is not defined

# %%
tundra_esports_data

# %%
tundra_esports_matches_df = tundra_esports_data.open_file()

# %%
tundra_esports_matches_df.head()
# Out:
#             start_date predict_team_name  predict_team_id  \
# 0  2022-10-23 00:17:21    Tundra Esports          8291895
# 1  2022-10-22 22:58:55    Tundra Esports          8291895
# 2  2022-10-21 14:05:39    Tundra Esports          8291895
# 3  2022-10-21 13:06:31    Tundra Esports          8291895
# 4  2022-10-18 18:17:15    Tundra Esports          8291895
#
#    predict_team_total_matches  predict_team_win_pct  predict_team_rating  \
# 0                         261                 62.84              1565.76
# 1                         261                 62.84              1565.76
# 2                         261                 62.84              1565.76
# 3                         261                 62.84              1565.76
# 4                         261                 62.84              1565.76
#
#    predict_players_mmr_average opposing_team_name  opposing_team_id  \
# 0                       7692.6         Team Aster           6209166
# ...

# %%
tundra_esports_matches_json = process_team_data('tundra_esports_data.json')

# %%
tundra_esports_matches_json[0]
# Out:
# {'match_id': 6817434540,
#  'radiant_win': False,
#  'radiant': False,
#  'duration': 2407,
#  'start_time': 1666444641,
#  'leagueid': 14268,
#  'league_name': 'The International 2022',
#  'cluster': 154,
#  'opposing_team_id': 6209166,
#  'opposing_team_name': 'Team Aster',
#  'opposing_team_logo': 'https://steamusercontent-a.akamaihd.net/ugc/1629730253163462144/FEF15B2B4528E81103DD693E37FD7B6C9BE6B471/',
#  'predict_players': [{'account_id': 10366616,
#    'name': 'Sneyking',
#    'player_stats': {'profile': {'account_id': 10366616,
#      'personaname': 'Sneyking',
#      'name': 'Sneyking',
#      'plus': True,
#      'cheese': 0,
#      'steamid': '76561197970632344',
#      'avatar': 'https://avatars.akamai.steamstatic.com/c19fed8e57530f749e3de139ae938a5fdbf051c5.jpg',
#      'avatarmedium': 'https://avatars.akamai.steamstatic.com/c19fed8e57530f749e3de139ae938a5fdbf051c5_medium.jpg',
# ...
